# %% [markdown]
# 1. Entre com dois números inteiros e exiba:
# a) A soma
# b) A subtração
# c) A multiplicação
# d) A divisão
# e) O resto da divisão

# %%
a = 8
b = 2
print(f"A: {a} B: {b}")
print(f"A soma de A e B é: {a + b}")
print(f"A subtração de A e B é: {a - b}")
print(f"A multiplicação de A e B é: {a * b}")
print(f"A divisão de A e B é: {a / b}")
print(f"O resto de A e B é: {a % b}")
# Out:
# A: 8 B: 2
# A soma de A e B é: 10
# A subtração de A e B é: 6
# A multiplicação de A e B é: 16
# A divisão de A e B é: 4.0
# O resto de A e B é: 0

# %% [markdown]
# 2. Entre com dois números e exiba a soma e a diferença entre eles.

# %%
a = 8
b = 2
print(f"A: {a} B: {b}")
print(f"A soma de A e B é: {a + b}")
print(f"A diferença de A e B é: {a - b}")
# Out:
# A: 8 B: 2
# A soma de A e B é: 10
# A diferença de A e B é: 6

# %% [markdown]
# 3. Entre com dois números, calcule e exiba o produto e o quociente (divisão real e
# inteira).

# %%
a = 8
b = 2
print(f"A: {a} B: {b}")
print(f"O produto de A e B é: {a * b}")
print(f"A divisão real de A e B é: {a / b}")
print(f"A divisão inteira de A e B é: {a // b}")
# Out:
# A: 8 B: 2
# O produto de A e B é: 16
# A divisão real de A e B é: 4.0
# A divisão inteira de A e B é: 4

# %% [markdown]
# 4. Entre com um número ao usuário e exiba se ele é par ou ímpar usando o operador de
# módulo %.

# %%
num = 8
print(f"num: {8}")
if num % 2 == 0:
    print("O número é par.")
else:
    print("O número é ímpar.")
# Out:
# num: 8
# O número é par.

# %% [markdown]
# 5. Entre com dois números e calcule a potência do primeiro elevado ao segundo.

# %%
a = 8
b = 2
print(f"A: {a} B: {b}")
print(f"A potência de A elevado a B é: {a ** b}")
# Out:
# A: 8 B: 2
# A potência de A elevado a B é: 64

# %% [markdown]
# 6. Entre com três números e exiba a média aritmética deles.

# %%
a = 8
b = 2
c = 6
print(f"A: {a} B: {b} C: {c}")
media = (a + b + c) / 3
print(f"A média de A, B e C é: {media}")
# Out:
# A:8 B:2 C:6
# A média de A, B e C é: 5.333333333333333

# %% [markdown]
# 7. Entre com um número e utilize operadores de atribuição para realizar as seguintes
# operações, imprimindo o resultado a cada etapa:
#
# a) Adicione 5 ao número
#
# b) Multiplique o valor por 2
#
# c) Subtraia 3
#
# d) Divida por 2
#
# e) Tire o resto da divisão por 3

# %%
a = 8
print(f"A: {a}")
a += 5
print(f"A variável A teve seu valor atribuido. Após adicionar 5: {a}")
a *= 2
print(f"A variável A teve seu valor atribuido. Após multplicar por 2: {a}")
a -= 3
print(f"A variável A teve seu valor atribuido. Após subtrair 3: {a}")
a /= 2
print(f"A variável A teve seu valor atribuido. Após dividir por 2: {a}")
a %= 3
print(f"A variável A teve seu valor atribuido. Após dividir por 3 e verificar o resto, obteve-se: {a}")
# Out:
# A: 8
# A variável A teve seu valor atribuido. Após adicionar 5: 13
# A variável A teve seu valor atribuido. Após multplicar por 2: 26
# A variável A teve seu valor atribuido. Após subtrair 3: 23
# A variável A teve seu valor atribuido. Após dividir por 2: 11.5
# A variável A teve seu valor atribuido. Após dividir por 3 e verificar o resto, obteve-se: 2.5

# %% [markdown]
# 8. Entre com dois números e exiba as comparações:
#
# a) Se o primeiro número é maior que o segundo
#
# b) Se os dois números são iguais
#
# c) Se o primeiro número é menor ou igual ao segundo

# %%
a = 8
b = 2
print(f"A: {a} B: {b}")
maior = a > b
print(f"A é maior que B?: {maior}")
igual = a == b
print(f"A é igual a B?: {igual}")
menorOuIgual = a <= b
print(f"A é menor ou igual a B?: {menorOuIgual}")
# Out:
# A:8 B:2
# A é maior que B?: True
# A é igual a B?: False
# A é menor ou igual a B?: False

# %% [markdown]
# 9. Entre com duas idades. Com base nessas informações, verifique se ambos tem mais de 18.

# %%
idade1 = 18
idade2 = 20
print(f"Idade 1: {idade1} Idade 2: {idade2}")
comparacao = idade1 > 18 and idade2 > 18
print(f"Ambos tem mais de 18 anos?: {comparacao}")
# Out:
# Idade 1: 18 Idade 2: 20
# Ambos tem mais de 18 anos?: False

# %% [markdown]
# 10. Solicite ao usuário uma palavra e verifique se a letra &quot;a&quot; está presente nela, utilizando
# o operador in.

# %%
palavra = "python"
print(f"Palavra: {palavra}")
comparacao = "p" in palavra
print(f"Existe a letra p na palavra?: {comparacao}")
# Out:
# Palavra: python
# Existe a letra p na palavra?: True

# %% [markdown]
# 11. Crie uma lista com 6 itens e verifique se existe uma palavra dentro dela, utilizando o
# operador in. Depois, verifique uma palavra que não existe dentro dela utilizando o
# operador not in.

# %%
frutas = ["maçã", "banana", "laranja", "abacaxi", "uva", "morango"]
print(f"Lista de frutas: {frutas}")
maca = "maçã" in frutas
print(f"Têm maçã na lista?: {maca}")
ameixa = "ameixa" not in frutas
print(f"Não têm maçã na lista?: {ameixa}")
# Out:
# Lista de frutas: ['maçã', 'banana', 'laranja', 'abacaxi', 'uva', 'morango']
# Têm maçã na lista?: True
# Não têm maçã na lista?: True
