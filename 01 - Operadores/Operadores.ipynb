# %% [markdown]
# ***Operadores Aritméticos***

# %%
x = 6 + 4 * 2
print(x)
# Out:
# 14

# %%
x = 4 * 9 + 5
print(x)
# Out:
# 41

# %%
x = (6 + 7) * 9
print(x)
# Out:
# 117

# %%
x = 15 + 20 - 30
print(x)
# Out:
# 5

# %% [markdown]
# ***Operadores de Atribuição***

# %%
x =12
x += 6
print(x)
# Out:
# 18

# %%
x =12
x -= 7
print(x)
# Out:
# 5

# %%
x =12
x *= 35
print(x)
# Out:
# 420

# %%
x = 12
x /= 2
print(x)
# Out:
# 6.0

# %% [markdown]
# ***Operadores de Comparação***

# %%
x = 51
x1 = 98
xresult = x < x1
print(xresult)
# Out:
# True

# %%
x = 51
x1 = 98
xresult = x == x1
print(xresult)
# Out:
# False

# %%
x = 51
x1 = 98
xresult = x >= x1
print(xresult)
# Out:
# False

# %%
x = 51
x1 = 98
xresult = x != x1
print(xresult)
# Out:
# True

# %% [markdown]
# ***Operadores Lógicos***

# %%
idade_caique = 30
idade_jessica = 24
comparação = not (idade_caique <= 18 and idade_jessica <= 18)
print(comparação)
# Out:
# True

# %% [markdown]
# ***Operadores de Identidade***

# %%
x = "botafogo"
x1 = "flamengo"
x2 = "botafogo"
xresult = x is x2
print(xresult)
# Out:
# True

# %%
x = "botafogo"
x1 = "flamengo"
x2 = "botafogo"
xresult = x is not x1
print(xresult)
# Out:
# True

# %%
x = "botafogo"
x1 = "flamengo"
x2 = "botafogo"
xresult = x1 is x2
print(xresult)
# Out:
# False

# %%
x = "botafogo"
x1 = "flamengo"
x2 = "botafogo"
xresult = x1 is not x2
print(xresult)
# Out:
# True

# %% [markdown]
# ***Operadores de Associação***

# %%
frutas = [ "banana", "laranja", "uva", "ameixa"]
x = "banana"
x1 = "laranja"
x2 = "abacaxi"

xresult = x in frutas
print(xresult)

xresult = x not in frutas
print(xresult)

xresult = x1 not in frutas
print(xresult)

xresult = x2 in frutas
print(xresult)
# Out:
# True
# False
# False
# False

# %% [markdown]
# ***Atividades***

# %%
x = 4
x1 = 9
x2 = 5

xresult = (((2 + 5) * 3) + x + 5) < x1
print(xresult)

xresult = (((2 + 5) * 3) + (x + 5 < x1) == (x == 6 + x2 * 2))
print(xresult)

xresult = (((3 * 6) + x - 3) < x2)
print(xresult)

xresult = (((7 * 8) > (x + 4 > x1) < (x != 2 + x2 * 9)))
print(xresult)
# Out:
# False
# False
# False
# True
